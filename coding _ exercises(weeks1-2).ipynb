# %% [markdown]
# # Weeks 1-2
# Prior to embarking on 12 weeks of tasks, to improve understanding on programming concepts. It was important to gain understaing on what code actually is. My understanding of code, is that it is like an umbrella term. Any type of code is made up of algorythims. An algorythim can be defined as a step-by-step process of completing a tasks or solving an issue. Algorithims can be displayed in human or computer language. While the idea of code can be intimidating for a beginner, once one has a grasp on fundamental functions it can become easier to read and understand. In starting to grasp concepts, pseudocode was useful. pseudocode can be defined as a simplified way of explaining what code should do and uses human language.
#
# The following notebooks display the use of python. Python is a universally popular coding language to do its accsesibility and through refelction of using it, I am able to understand why it is favoured over other coding languages.

# %% [markdown]
# ### I began this project by navigating to GitHub
#
# #### Step 1: Learn about GitHub
# I begain by learing about GitHub, to help with this process I watched a Youtube video from Net Ninga(https://www.youtube.com/watch?v=3RjQznt-8kE). This explained some of the basics, i learned that GitHub is a space which allows both collabortation and version control. It is also useful as it allows users to track changes they have made to their project.
#
# #### Step 2 and 3 : Creating a GitHub account and learning about repositories
# I created an account and set out to learn about basic repositories. The "Hello World!" page was the first thing I read and was useful when gathering basic concepts.
#
# - I created my repository called "AI-FOR-THE-ARTS."
# - I made sure the tick the box for a READMEfile
# - I set an appropriate licence (MIT)
# - I created a branch called readme-edit
# - I sucsessfully created a pull reguest and merged work I put into my readme edit to my README file
#
# #### Step 4: Styling README
# - I next learned about the use of headings and how they differ from HTML. The website,(https://www.markdownguide.org/basic-syntax/) explained headings can be created through hashtag symbols and through equals signs benath them.
# - I used the pencil icon to edit and update my README with relevant information.
# - Finally, once I was happy with it I made sure to commit my changes
#
# The result of this work can all be displayed in my README file.
#
#
# #### Step 5 and 6: Uploading and deleting content from repositories
# - I also learned how to upload and delete content from my repository. To upload, navigate to the "add files" button, selected the upolad files option, select files and then add a message when commiting changes. To delete, click on the file you want to delete, click the three dots, click on the delte file option, add a message before commiting the change.
# #### Step 7: Checking changes in repositories
# - Once everything was saved, I was able to navigate to my commits (this is where you can view the changes you have made). Furthermore, it highlights the importance of writing what you have changed while editing, to make specific changes easier to locate.
#
# ### Reflection
# Reflecting on this first task, I found it hard to navigate particularly with the pull requested and merging it. However, after completing this task I feel more confident in my abilities. I learned about headings as well as how to upload and delete files. I aso learned about the importance of writting messages alogside commiting changes. Aditionally, I learned for best bractice, to use branches before uploading to the main. As mentioned, these tasks are displayed on the README page of this portfolio of work.

# %% [markdown]
# # Introduction to GitHub Codespaces
# #### Step 1: What are GitHub codepaces?
# - GitHub codespaces are a cloud based code environment.
# - It runs through web browser
# - You need to commit and sync changes to view them in your GitHub repository
# - They are a prime space for coding
#
# #### Step 2 and 3
# The next step I took was navigating to my repository, from that I located to the green code button and opened my codespace.
#
# #### Step 4 and 5
# Furthermore, I then created a Jupyter notebook by navigating to the explorer pannel (clicking newfile). I named this "coding exercises(weeks1-2).ipynb". I chose to include the "weeks 1-2" to help keep better track of my progress and to create a clear layout for the reader. The ".ipynb" is the essential part of this file (this extention is requited for a Jupyter notebook file)
#
# From here I was able to navigate to the "code" and "markdown" cell options.
#
# In the next part of this markdown I aim to learn about more basic programming concepts as well as imporove my ability to read code and identify errors.

# %% [markdown]
# ## "Hello, world!" program
#  This code is my first attempt at programming. I am learning how to run and write code within a girthub codespace.

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# After this task I saved and synced my work by navigating to the source control, and adding a message before commiting and syncing changes.

# %% [markdown]
# ### Enabling Python and Jupyter Extensions of GitHub Codespaces
# I first bagan by making sure both python and Jupyter extensions were downloaded and set before proceding with next steps.
#
# ### Using microsoft Copilot as an AI-Assistent
# Copilot is an AI assistent which has been ighlighted to increase productivity. It has been integrated into other microsoft applications such as word ad powerpoint to improve them.
# ### First time testing Microsoft co-pilot with python
#  I used microsoft copilot to create a basic python "Hello, world!" program as well as asked it to explain how the code worked in a simple way
# #### The prompt I put into co-pilot
# - "Could you suggest a python code for ‘Hello, world!’to demonstrate the concept of printing to a complete beginner in programming? Please explain the code step-by-step highlighting any key aspects"
# #### The respone co-pilot generated:
#
# "print(...) — a built-in function"
# print is a function that displays text or values on the screen and is seen to be the fastest way to check output of a cell
#
# "Parentheses () — calling the function"
# It explains that you put in brackets next to print what you want to show and it will produce as the output
#
#
#  ""Hello, world!" — a string"
# A string is a sequence of characters (letters, spaces, punctuation) put inbetween quotes.(either '' or "")
#
# As well as this step-by-step guide, it also generated common mistakes of begginers such as missing quotes and mismatched quotes. It further generated code to highlight these mistakes. Aditionally Copilot was helpful as it generated practice tasks users could benefit from if they were unsure in their understanding. To relect copilot was able to teach me about how the print function is a built in function and how it is efficient in seeing outputs. It taught me about the use of parentheses and how what you put inside then is what you want to show. Finally it taught me about a string and how they are a line of characters (that must have quotes surroundig them)
#
# #### What I learned from this task:
# - I learnd how to run a basic python program
# - I learned about the purpose of print()
# - I learned about the importance of enclosing text ("",'') as it is written as a string
# - I learned that Copilot has a vast Knowledge on this function and was helpful in providing a lot of information
# #### Below I insterted the further practice tasks of code co-pilot asked me to put in.

# %%
print("Hi Eloise")
# Out:
# Hi Eloise

# %%
print("Hello,", end="")
print("world!")
# Out:
# Hello,world!

# %%
msg = "Hello, world!"
print(msg)
# Out:
# Hello, world!

# %% [markdown]
# Running this aditional code further helped to consolidate knowledge on the print() function in python as one is able to visually see what Copilot is explaining along with text.

# %% [markdown]
# ### When reflecting on these tasks, I feel my understading of Copilots value in learning about the print() function has been useful. Prior to this, I knew Copilot would be knowledgable, however as I was unfamiliar with the application I was unsure if I would find it helpful in my learning. However, it provided me with detailed step-by step instructions that were easy to follow as well as helped me practice by generating me code to run, which has allowed me to reflect and learn about the print() function in python code. Overall these tasks have contributed to fufilling the aims I have regarding completion of this potfolio.
#
# Extra note: When coming back to edit and update this file, I had an error in syncing my work back with my Github. While in the past I would have been stressed, I reflected and thought about what was causing this, why it was happening, and the steps I nedded to take to fix it. I began by looking through the error messages to find it saying "divergent error". I consulted Copilot with my issue, it was able to generate multiple examles of things to try. After reading through I selected the option I felt would work the best and inserted it into my terminal to try and mitigate this syning error. It worked!. This further has aided in my understanding in troubleshooting an error, learning not to panic and to think logically about what the error message is saying. Aditionally, it has furthered my understanding of how Copilot can be used as an efficient tool in eliminating errors nd learning how to resolve basic coding errors.
