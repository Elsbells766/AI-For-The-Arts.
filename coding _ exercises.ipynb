# %% [markdown]
# # First coding markdown
# ##
# ## Goals
# - I aim to understand how code chunks work and how they can be beneficial
# - I aim to use python
# - I aim to use Jupyter notebook

# %% [markdown]
# # Hello, world
# ## This code is my first attempt at programming. I am learning how to run and write code within a girthub codespace.

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# # First time testing Microsoft co-pilot with python
# ## I used microsoft co-pilot to create a basic python "Hello, world!" program as well as asked it to explain how the code worked in a simple way
# ### The prompt I put into co-pilot
# - Could you suggest a python code for ‘Hello, world!’to demonstrate the concept of printing to a complete beginner in programming? Please explain the code step-by-step highlighting any key aspects
# ### The respone co-pilot gave
# - Parentheses () are used to pass information, the contense inside them will become the output
# - Python does not reqire semi colons, which is unlike many other popular coding programs
# - The word "print" is the function
# - In python text is written as a string, therfor you must enclose it ("",'')
# ### What I learned from this task:
# - I learnd how to run a basic pythin program
# - I learned about the purpose of print()
# - I learned about the importance of enclosing text ("",'') as it is written as a string
# ### Below I insterted the suggestions of code co-pilot asked me to put in.

# %%
print("Hi from Glasgow!")
# Out:
# Hi from Glasgow!

# %%
print("Hello,", "world!")
# Out:
# Hello, world!

# %%
print('Hello, world!')
# Out:
# Hello, world!
