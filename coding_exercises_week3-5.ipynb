# %% [markdown]
# # Week 3-5: Understanding Code
# ## In this section of my portfolio I will be displaying my learning of basic programming concepts
#
# ## Step 1: Run some prompts in Microsoft Copilot
# ### 1. Variables
# ### I began by running " Could you suggest a modification of the Python code for “Hello, world!” to demonstrate the concept of variables to a complete beginner in programming? Please explain the code step-by-step highlighting any key aspects" into copilot
#
# - ## prompts that copilot suggested;

# %%
message = "Hello, world!"
print(message)
# Out:
# Hello, world!

# %% [markdown]
# ### This was the first prompt copilot suggested.
# ### Copilot then discussed;
# - The variable creation. it explained that in this example "message" is the name and "Hello, world!" is the value
# - Assignment opperator, meaning the "=" is sayingto "store this in there"
# - String value, highlighting that you must use ("" or '')
# - Printing the varibales, That python looks st the value stored in "message"
# ### How this information is useful
# - I learned that this makes it easy to modify code (If you change that value in once it automatically updates it everywhere)
# ### Below I have inserted another two code chunks copilot suggested

# %%
message = "Hello, world!"
print(message)

message = "Hi from Glasgow!"
print(message)
# Out:
# Hello, world!
# Hi from Glasgow!

# %%
name = "El"
greeting = "Hello"
print(greeting + ", " + name + "!")      # concatenation
print(f"{greeting}, {name}!")            # f-string (formatted string)
# Out:
# Hello, El!
# Hello, El!

# %% [markdown]
# ### Overall, I found co pilot useful in develpping my understanding of variables in python
#
# ## 2. Functions
# ### I put this prompt into copilot, "Could you suggest a modification of the Python code for “Hello, world!” to demonstrate the concept of functions to a complete beginner in programming? Please explain the code step-by-step highlighting any key aspects"
#
# - ## prompts copilot suggested;

# %%
def greet():
    print("Hello, world!")

greet()
# Out:
# Hello, world!

# %% [markdown]
# ### Copilot then discussed
# - Function definition
# - Function body
# - Function call
# ### This was useful in helping me understand the use of functions (instert usefulness)

# %%
def greet(message):
    print(message)

greet("Hello, world!")
greet("Hi, how are you!")
# Out:
# Hello, world!
# Hi, how are you!

# %%
def make_greeting(name):
    return f"Hello, {name}!"

text = make_greeting("El")
print(text)
# Out:
# Hello, El!

# %% [markdown]
# ### 3. loops
