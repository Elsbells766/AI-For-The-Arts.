# %% [markdown]
# ## Reflecting on Machine Learning
# #### In the next section below I will be highlighting

# %% [markdown]
# # Machine learning example: From start to end
#
# ## Discussion with peer group:
